# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(0,20,210)
plt.plot(x, np.cos(x))
plt.plot(x, np.cos(0.5*x))
plt.xlabel('x')
plt.ylabel('y')
plt.axis('tight')
plt.show()
